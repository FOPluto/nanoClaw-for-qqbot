# %%
from openai import OpenAI

# %%
client = OpenAI(
    api_key="ollama",
    base_url="http://localhost:11434/v1",
)

# %%
resp = client.embeddings.create(model="nomic-embed-text", input="测试").data[0].embedding

# %%
resp
# Out:
# 6184

# %%
import asyncio

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 7
#       3     await asyncio.sleep(1)
#       5 coro = demo()
# ----> 7 asyncio.run(coro)
#
# File ~/miniconda3/envs/valik/lib/python3.10/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
